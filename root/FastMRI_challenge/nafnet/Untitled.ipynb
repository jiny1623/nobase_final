# %%
import h5py
from pathlib import Path

for fname in sorted(list(Path("/Data/train/image/").iterdir())):
    print(fname / fname.name)
# with h5py.File("/Data/train/image" / "brain_acc4_1.h5", 'r') as rf:
#     print(rf.keys())
# Out:
# /Data/train/image/brain_acc4_1.h5/brain_acc4_1.h5
# /Data/train/image/brain_acc4_10.h5/brain_acc4_10.h5
# /Data/train/image/brain_acc4_100.h5/brain_acc4_100.h5
# /Data/train/image/brain_acc4_101.h5/brain_acc4_101.h5
# /Data/train/image/brain_acc4_102.h5/brain_acc4_102.h5
# /Data/train/image/brain_acc4_103.h5/brain_acc4_103.h5
# /Data/train/image/brain_acc4_104.h5/brain_acc4_104.h5
# /Data/train/image/brain_acc4_105.h5/brain_acc4_105.h5
# /Data/train/image/brain_acc4_106.h5/brain_acc4_106.h5
# /Data/train/image/brain_acc4_107.h5/brain_acc4_107.h5
# /Data/train/image/brain_acc4_108.h5/brain_acc4_108.h5
# /Data/train/image/brain_acc4_109.h5/brain_acc4_109.h5
# /Data/train/image/brain_acc4_11.h5/brain_acc4_11.h5
# /Data/train/image/brain_acc4_110.h5/brain_acc4_110.h5
# /Data/train/image/brain_acc4_111.h5/brain_acc4_111.h5
# /Data/train/image/brain_acc4_112.h5/brain_acc4_112.h5
# /Data/train/image/brain_acc4_113.h5/brain_acc4_113.h5
# /Data/train/image/brain_acc4_114.h5/brain_acc4_114.h5
# ...
